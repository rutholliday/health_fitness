# %%
#importing dependencies
import pandas as pd
from sqlalchemy import create_engine
import datetime
import numpy as np

# %%
#defining the CSV Variable
National_Health_Expenditures_csv = '../Resources/CSV_files/National_Health_Expenditures_simple.csv'

#Reading the csv in as AND NEED TO TAKE OFF THE NROWS (nrows=5)
National_Health_Expenditures_df = pd.read_csv(National_Health_Expenditures_csv)
National_Health_Expenditures_df
# Out:
#    Year  National_health_expenditures  Health_consumption_expenditures  \
# 0  1960                          27.2                             24.7
# 1  1970                          74.6                             67.0
# 2  1975                         133.3                            121.1
# 3  1980                         255.3                            235.5
# 4  1990                         721.4                            674.1
# 5  2000                        1369.1                           1285.8
# 6  2009                        2495.4                           2356.5
# 7  2015                        3200.8                           3047.1
# 8  2016                        3337.2                           3179.8
#
#    Personal_health_care  Hospital_care  Professional_services  \
# 0                  23.3            9.0                    7.9
# 1                  63.1           27.2                   19.8
# 2                 113.2           51.2                   34.7
# ...

# %%
National_Health_Expenditures_df.shape
# Out:
# (9, 22)

# %%
National_Health_Expenditures_df.columns
# Out:
# Index(['Year', 'National_health_expenditures',
#        'Health_consumption_expenditures', 'Personal_health_care',
#        'Hospital_care', 'Professional_services',
#        'Physician_and_clinical_services', 'Other_professional_services',
#        'Dental_services', 'Other_health_residential_and_personal_care',
#        'Home_health_care1',
#        'Nursing_care_facilities_and_care_retirement_communities1',
#        'Retail_outlet_sales_of_medical_products', 'Prescription_drugs',
#        'Durable_medical_equipment', 'Other_nondurable_medical_products',
#        'Government_administration2', 'Net_cost_of_health_insurance3',
#        'Government_public_health_activities4', 'Investment', 'Research5',
#        'Structures_and_equipment'],
#       dtype='object')

# %%
#importing dependencies for mysql connection
import pymysql
pymysql.install_as_MySQLdb()

#just have to change this to your password for local access to your sqlsql database
sql_password = 'CassiusClay2!'
db_name = 'Health_Trend_Project_db'

#connecting to my sql database
rds_connection_string = "root:"+sql_password+"@127.0.0.1/"+db_name
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['national_health_expenditures_data']

# %%
#Loading data to kickstarter mysql table
National_Health_Expenditures_df.to_sql(name='national_health_expenditures_data', con=engine, if_exists='append', index=False)
# Out:
# C:\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'National_health_expenditures' at row 1")
#   result = self._query(query)
# C:\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'Health_consumption_expenditures' at row 1")
#   result = self._query(query)
# C:\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'Personal_health_care' at row 1")
#   result = self._query(query)
# C:\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'Professional_services' at row 1")
#   result = self._query(query)
# C:\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'Physician_and_clinical_services' at row 1")
#   result = self._query(query)
# C:\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'Other_professional_services' at row 1")
# ...
