# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import colors as mcolors 

# Read the labor_fitness csv 
labor_fitness = pd.read_csv("occupation_fitness.csv")

# Display the data table for preview
labor_fitness.head()
# Out:
#                                     Occupation_Title    1999    2000    2001  \
# 0                    Athletes and sports competitors   10620    9920   10520
# 1                                  athletic Trainers   16670   13820   12580
# 2  recreation and fitness studies teachers, posts...   14970   14050   14700
# 3           fitness trainers and aerobic instructors  127310  157230  160490
# 4                                   health educators   41620   43670   43890
#
#      2002    2003    2004    2005    2006    2007    2008    2009    2010  \
# 0   10400   11840   12250   12230   12500   12670   13960   13620   12660
# 1   13500   11750   13100   15110   15440   14970   15070   15260   16290
# 2   14650   14780   15470   16530   17110   17500   17410   16850   17720
# 3  169920  177790  182280  189220  205970  219990  229030  228170  225490
# 4   43240   42780   46490   51970   57900   61290   62120   63320   58150
#
#      2011    2012    2013    2014    2015    2016    2017
# 0   12630   12450   13880   11520   11710   10260   11150
# 1   18240   20780   22340   22400   23450   24130   25010
# 2   18660   19410   18820   18650   17980   17390   16630
# 3  231500  234070  238170  241000  237760  257410  280080
# 4   56610   55270   56720   57020   57570   57570   58040

# %%
plt.title("Labor changes in the fitness Industry")

# urban = combined_csv[combined_csv.type == 'Urban']
danger_drop = plt.plot(labor_fitness["1999"], labor_fitness["Occupation_Title"], color="red", label="Danger Drop")
railgun = plt.plot(labor_fitness["1999"], labor_fitness["Occupation_Title"], color="blue", label="RailGun")
